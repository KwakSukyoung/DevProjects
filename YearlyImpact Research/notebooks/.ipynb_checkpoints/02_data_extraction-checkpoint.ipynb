# %%
import numpy as np
import pandas as pd
import json
import sqlite3
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
## 1. Connect to the Database
conn = sqlite3.connect("../data/thanksgiving_point.db")
print("Database connection successful.")
# Out:
# Database connection successful.

# %%
## 2. Check available tables
tables = pd.read_sql_query(
    """
    SELECT name
    FROM sqlite_master
    WHERE type = 'table'
    ORDER BY name;
    """,
    conn
)

tables
# Out:
#                name
# 0          children
# 1        households
# 2  survey_responses
# 3            visits

# %%
## 3. Extract households
households_df = pd.read_sql_query("SELECT * FROM households;",conn)

households_df
# Out:
#       household_id  family_size  adults  children_count  average_child_age
# 0           H00001            4       2               2                1.5
# 1           H00002            5       2               3                6.0
# 2           H00003            3       2               1                4.0
# 3           H00004            2       2               0                NaN
# 4           H00005            5       2               3                4.0
# ...            ...          ...     ...             ...                ...
# 99995       H99996            6       2               4                6.0
# 99996       H99997            4       2               2                8.0
# 99997       H99998            2       2               0                NaN
# 99998       H99999            5       2               3                6.0
# 99999      H100000            5       1               4                8.0
#
# [100000 rows x 5 columns]

# %%
## 4. Extract children
children_df = pd.read_sql_query("SELECT * FROM children;", conn)
children_df
# Out:
#           child_id household_id  age
# 0        H00001_C1       H00001    1
# 1        H00001_C2       H00001    2
# 2        H00002_C1       H00002    4
# 3        H00002_C2       H00002    6
# 4        H00002_C3       H00002    8
# ...            ...          ...  ...
# 244137   H99999_C3       H99999    9
# 244138  H100000_C1      H100000    2
# 244139  H100000_C2      H100000    6
# 244140  H100000_C3      H100000   10
# 244141  H100000_C4      H100000   14
#
# [244142 rows x 3 columns]

# %%
## 5. Extract visits
visits_df = pd.read_sql_query("SELECT * FROM visits;",conn)

visits_df
# Out:
#           visit_id household_id  visit_date  visit_number  \
# 0        H00001_V1       H00001  2026-01-18             1
# 1        H00001_V2       H00001  2026-09-03             2
# 2        H00001_V3       H00001  2026-09-06             3
# 3        H00001_V4       H00001  2026-07-15             4
# 4        H00001_V5       H00001  2026-05-15             5
# ...            ...          ...         ...           ...
# 308892   H99998_V2       H99998  2026-03-02             2
# 308893   H99998_V3       H99998  2026-01-26             3
# 308894   H99998_V4       H99998  2026-06-11             4
# 308895   H99999_V1       H99999  2026-08-24             1
# 308896  H100000_V1      H100000  2026-04-28             1
#
#                     exhibit  crowd_density  number_of_programs  spending
# 0                   Gardens      44.150495                   4     39.63
# 1                   Gardens      43.584904                   3     71.70
# ...

# %%
## 6. Extract survey responses
survey_df = pd.read_sql_query("SELECT * FROM survey_responses;",conn)

survey_df
# Out:
#             survey_id    visit_id household_id  satisfaction  learning_score  \
# 0        H00001_V1_S1   H00001_V1       H00001          3.29            4.92
# 1        H00001_V2_S1   H00001_V2       H00001          3.03            4.56
# 2        H00001_V3_S1   H00001_V3       H00001          3.96            3.45
# 3        H00001_V4_S1   H00001_V4       H00001          3.66            3.02
# 4        H00001_V5_S1   H00001_V5       H00001          3.15            2.88
# ...               ...         ...          ...           ...             ...
# 308892   H99998_V2_S1   H99998_V2       H99998          5.00            3.49
# 308893   H99998_V3_S1   H99998_V3       H99998          4.17            2.78
# 308894   H99998_V4_S1   H99998_V4       H99998          3.50            3.76
# 308895   H99999_V1_S1   H99999_V1       H99999          4.99            2.63
# 308896  H100000_V1_S1  H100000_V1      H100000          4.01            4.02
#
# ...

# %%
## 8. Check the structure of each table
print("HOUSEHOLDS")
households_df.info()

print("\nCHILDREN")
children_df.info()

print("\nVISITS")
visits_df.info()

print("\nSURVEY RESPONSES")
survey_df.info()
# Out:
# HOUSEHOLDS
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 5 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   household_id       100000 non-null  object
#  1   family_size        100000 non-null  int64
#  2   adults             100000 non-null  int64
#  3   children_count     100000 non-null  int64
#  4   average_child_age  93237 non-null   float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 3.8+ MB
#
# CHILDREN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244142 entries, 0 to 244141
# Data columns (total 3 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   child_id      244142 non-null  object
#  1   household_id  244142 non-null  object
#  2   age           244142 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 5.6+ MB
#
# VISITS
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
## 9. Check missing values
print("Households missing values:")
display(households_df.isnull().sum())

print("Children missing values:")
display(children_df.isnull().sum())

print("Visits missing values:")
display(visits_df.isnull().sum())

print("Survey responses missing values:")
display(survey_df.isnull().sum())
# Out:
# Households missing values:
# household_id            0
# family_size             0
# adults                  0
# children_count          0
# average_child_age    6763
# dtype: int64
# Children missing values:
# child_id        0
# household_id    0
# age             0
# dtype: int64
# Visits missing values:
# visit_id              0
# household_id          0
# visit_date            0
# visit_number          0
# exhibit               0
# crowd_density         0
# number_of_programs    0
# spending              0
# dtype: int64
# Survey responses missing values:
# survey_id                   0
# visit_id                    0
# household_id                0
# satisfaction                0
# learning_score              0
# curiosity_score             0
# confidence_score            0
# social_interaction_score    0
# return_intent               0
# recommend_score             0
# comments                    0
# dtype: int64

# %%
## 10. Check relationships between tables
print("Household IDs:", households_df["household_id"].nunique())
print("Child household IDs:", children_df["household_id"].nunique())
print("Visit household IDs:", visits_df["household_id"].nunique())
print("Survey household IDs:", survey_df["household_id"].nunique())
# Out:
# Household IDs: 100000
# Child household IDs: 93237
# Visit household IDs: 100000
# Survey household IDs: 100000
