# %% [markdown]
# ***Qualitative Research***
# - We will first create 100 synthetic comments.
# - Then categorize them.
# - categorize and analyze the guest comments.

# %%
import numpy as np
import pandas as pd
import statsmodels.models as smf

# %%
themes = {
    "Satisfaction": [
        "satisfied",
        "happy",
        "enjoyed",
        "great experience",
        "wonderful",
        "excellent",
        "positive experience",
        "fun",
        "amazing",
        "disappointed"
    ],

    "Learning": [
        "learned",
        "learning",
        "educational",
        "knowledge",
        "understand",
        "taught",
        "discovered",
        "informative",
        "new things",
        "science"
    ],

    "Booth Participation": [
        "booth",
        "activity booth",
        "participated",
        "participate",
        "hands-on activity",
        "activity",
        "interactive activity",
        "booth activity",
        "participated in the booth",
        "skipped the booth"
    ],

    "Spending": [
        "spent",
        "spending",
        "money",
        "expensive",
        "price",
        "cost",
        "admission price",
        "food",
        "snacks",
        "gift shop"
    ],

    "Education Program": [
        "education program",
        "educational program",
        "program",
        "class",
        "lesson",
        "instructor",
        "educator",
        "educational activity",
        "education",
        "learning program"
    ],

    "Return Intent": [
        "come back",
        "return",
        "visit again",
        "next visit",
        "future visit",
        "come again",
        "would return",
        "visit in the future",
        "come back again",
        "recommend"
    ]
}
